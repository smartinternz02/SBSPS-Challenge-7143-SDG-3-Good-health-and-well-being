# %%
#reading the data set
import pandas as pd
df = pd.read_csv('dataset.csv')
df.head(3)
# Out:
#    Sl.No                          Category  \
# 0    1.0  Population and Household Profile
# 1    2.0  Population and Household Profile
# 2    3.0  Population and Household Profile
#
#                                 Indicators (2019-20) Urban Rural  \
# 0  1. Female population age 6 years and above who...  75.9  52.4
# 1               2. Population below age 15 years (%)  23.4    22
# 2  3. Sex ratio of the total population (females ...  1015  1070
#
#   Total (2019-20) Total (2015-16) Adilabad Bhadradri Hyderabad  ...  \
# 0            60.9            62.6     58.6      62.7      80.3  ...
# 1            22.5            25.1     24.8      19.5        23  ...
# 2            1049            1007      992      1082       959  ...
#
#   Rajanna Sircilla Ranga Reddy Sangareddy Siddipet Suryapet Vikarabad  \
# 0             56.4        68.6       60.2     60.8     57.4      53.1
# 1             21.3        24.1       24.5       22     18.9      24.9
# ...

# %%
#obtaining a particular category from dataset
dfnew=df.loc[df['Category'] == 'Quality of Family Planning Services' ]
dfnew.tail()
# Out:
#     Sl.No                             Category  \
# 29   30.0  Quality of Family Planning Services
# 30   31.0  Quality of Family Planning Services
#
#                                  Indicators (2019-20) Urban Rural  \
# 29  30. Health worker ever talked to female non-us...  17.2  16.9
# 30  31. Current users ever told about side effects...  52.4  47.2
#
#    Total (2019-20) Total (2015-16) Adilabad Bhadradri Hyderabad  ...  \
# 29              17             9.6       12      18.3      18.5  ...
# 30            49.2            25.1     32.6      51.3      58.2  ...
#
#    Rajanna Sircilla Ranga Reddy Sangareddy Siddipet Suryapet Vikarabad  \
# 29             18.9        18.7       10.2     11.6     16.6       8.6
# 30               60        53.4       47.5     46.7     36.9      36.5
#
#    Wanaparthy, Warangal Rural Warangal Urban Yadadri
# 29        22.3           16.3           27.8    20.6
# 30        36.6           53.5           49.4    58.5
#
# [2 rows x 38 columns]

# %%
dfnew.dtypes
# Out:
# Sl.No                       float64
# Category                     object
# Indicators (2019-20)         object
# Urban                       float64
# Rural                       float64
# Total (2019-20)             float64
# Total (2015-16)             float64
# Adilabad                    float64
# Bhadradri                   float64
# Hyderabad                   float64
# Jagitial                    float64
# Jangoan                     float64
# Jayashankar Bhupalapally    float64
# Jogulamba Gadwal            float64
# Kamareddy                   float64
# Karimnagar                  float64
# Khammam                     float64
# KumurumBheem                float64
# Mahabubabad                 float64
# Mahabubnagar                float64
# Mancherial                  float64
# Medak                       float64
# Medchal-Malkajgiri          float64
# Nagarkurnool                float64
# Nalgonda                    float64
# Nirmal                      float64
# ...

# %%
#converting objects to float
dfnew = dfnew.apply(pd.to_numeric, errors='ignore')
dfnew.dtypes
# Out:
# Sl.No                       float64
# Category                     object
# Indicators (2019-20)         object
# Urban                       float64
# Rural                       float64
# Total (2019-20)             float64
# Total (2015-16)             float64
# Adilabad                    float64
# Bhadradri                   float64
# Hyderabad                   float64
# Jagitial                    float64
# Jangoan                     float64
# Jayashankar Bhupalapally    float64
# Jogulamba Gadwal            float64
# Kamareddy                   float64
# Karimnagar                  float64
# Khammam                     float64
# KumurumBheem                float64
# Mahabubabad                 float64
# Mahabubnagar                float64
# Mancherial                  float64
# Medak                       float64
# Medchal-Malkajgiri          float64
# Nagarkurnool                float64
# Nalgonda                    float64
# Nirmal                      float64
# ...

# %%
dfnew.head()
# Out:
#     Sl.No                             Category  \
# 29   30.0  Quality of Family Planning Services
# 30   31.0  Quality of Family Planning Services
#
#                                  Indicators (2019-20)  Urban  Rural  \
# 29  30. Health worker ever talked to female non-us...   17.2   16.9
# 30  31. Current users ever told about side effects...   52.4   47.2
#
#     Total (2019-20)  Total (2015-16)  Adilabad  Bhadradri  Hyderabad  ...  \
# 29             17.0              9.6      12.0       18.3       18.5  ...
# 30             49.2             25.1      32.6       51.3       58.2  ...
#
#     Rajanna Sircilla  Ranga Reddy  Sangareddy  Siddipet  Suryapet  Vikarabad  \
# 29              18.9         18.7        10.2      11.6      16.6        8.6
# 30              60.0         53.4        47.5      46.7      36.9       36.5
#
#     Wanaparthy,  Warangal Rural  Warangal Urban  Yadadri
# 29         22.3            16.3            27.8     20.6
# ...

# %%
#checking for null values if any
dfnew.isnull().sum()
# Out:
# Sl.No                       0
# Category                    0
# Indicators (2019-20)        0
# Urban                       0
# Rural                       0
# Total (2019-20)             0
# Total (2015-16)             0
# Adilabad                    0
# Bhadradri                   0
# Hyderabad                   0
# Jagitial                    0
# Jangoan                     0
# Jayashankar Bhupalapally    0
# Jogulamba Gadwal            0
# Kamareddy                   0
# Karimnagar                  0
# Khammam                     0
# KumurumBheem                0
# Mahabubabad                 0
# Mahabubnagar                0
# Mancherial                  0
# Medak                       0
# Medchal-Malkajgiri          0
# Nagarkurnool                0
# Nalgonda                    0
# Nirmal                      0
# Nizamabad                   0
# Peddapalli                  0
# Rajanna Sircilla            0
# Ranga Reddy                 0
# Sangareddy                  0
# ...

# %%
dfnew.columns
# Out:
# Index(['Sl.No', 'Category', 'Indicators (2019-20)', 'Urban', 'Rural',
#        'Total (2019-20)', 'Total (2015-16)', 'Adilabad', 'Bhadradri',
#        'Hyderabad', 'Jagitial', 'Jangoan', 'Jayashankar Bhupalapally',
#        'Jogulamba Gadwal', 'Kamareddy', 'Karimnagar', 'Khammam',
#        'KumurumBheem', 'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak',
#        'Medchal-Malkajgiri', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad',
#        'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy',
#        'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy,', 'Warangal Rural',
#        'Warangal Urban', 'Yadadri'],
#       dtype='object')

# %%
dfnew.describe(include="all")
# Out:
#             Sl.No                             Category  \
# count    2.000000                                    2
# unique        NaN                                    1
# top           NaN  Quality of Family Planning Services
# freq          NaN                                    2
# mean    30.500000                                  NaN
# std      0.707107                                  NaN
# min     30.000000                                  NaN
# 25%     30.250000                                  NaN
# 50%     30.500000                                  NaN
# 75%     30.750000                                  NaN
# max     31.000000                                  NaN
#
#                                      Indicators (2019-20)      Urban  \
# count                                                   2   2.000000
# unique                                                  2        NaN
# top     30. Health worker ever talked to female non-us...        NaN
# ...

# %%
 dfnew.mean(axis = 1)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_10560/2230867666.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfnew.mean(axis = 1)
# 29    17.372222
# 30    45.733333
# dtype: float64

# %% [markdown]
# #  Data Visualisation

# %%
import matplotlib as plt
dfnew.boxplot(rot=90,figsize=(20,20),patch_artist = True)
# Out:
# <AxesSubplot:>

# %%
ur=df.loc[[30,31],['Indicators (2019-20)','Urban','Rural']]
ur
# Out:
#                                  Indicators (2019-20) Urban Rural
# 30  31. Current users ever told about side effects...  52.4  47.2
# 31  32. Mothers who had an antenatal check-up in t...  89.8  87.6

# %%
#seperation of numerical and categorical variables
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
numerical_data=dfnew.select_dtypes(include=[np.number])
categorical_data=dfnew.select_dtypes(include=[np.object])
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_10560/2319937515.py:5: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical_data=dfnew.select_dtypes(include=[np.object])

# %%
total=df.loc[[30,31],['Indicators (2019-20)','Total (2019-20)', 'Total (2015-16)']]
total
# Out:
#                                  Indicators (2019-20) Total (2019-20)  \
# 30  31. Current users ever told about side effects...            49.2
# 31  32. Mothers who had an antenatal check-up in t...            88.5
#
#    Total (2015-16)
# 30            25.1
# 31            83.1

# %%
dist=df.loc[[30,31],['Indicators (2019-20)','Adilabad', 'Bhadradri',
       'Hyderabad', 'Jagitial', 'Jangoan', 'Jayashankar Bhupalapally',
       'Jogulamba Gadwal', 'Kamareddy', 'Karimnagar', 'Khammam',
       'KumurumBheem', 'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak',
       'Medchal-Malkajgiri', 'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad',
       'Peddapalli', 'Rajanna Sircilla', 'Ranga Reddy', 'Sangareddy',
       'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy,', 'Warangal Rural',
       'Warangal Urban', 'Yadadri']]

# %%
sns.pairplot(dfnew,x_vars=['Adilabad','Nirmal'],y_vars='Indicators (2019-20)',hue='Urban')
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)

# %%
#finding corelation 
f,ax=plt.subplots(figsize=(10,8))
plt.title('Correlation with Urban',y=1,size=16)
sns.heatmap(data=numerical_data.corr(),square=True)
# Out:
# <AxesSubplot:title={'center':'Correlation with Urban'}>

# %%
print(numerical_data.corr())
# Out:
#                           Sl.No  Urban  Rural  Total (2019-20)  \
# Sl.No                       1.0    1.0    1.0              1.0
# Urban                       1.0    1.0    1.0              1.0
# Rural                       1.0    1.0    1.0              1.0
# Total (2019-20)             1.0    1.0    1.0              1.0
# Total (2015-16)             1.0    1.0    1.0              1.0
# Adilabad                    1.0    1.0    1.0              1.0
# Bhadradri                   1.0    1.0    1.0              1.0
# Hyderabad                   1.0    1.0    1.0              1.0
# Jagitial                    1.0    1.0    1.0              1.0
# Jangoan                     1.0    1.0    1.0              1.0
# Jayashankar Bhupalapally    1.0    1.0    1.0              1.0
# Jogulamba Gadwal            1.0    1.0    1.0              1.0
# Kamareddy                   1.0    1.0    1.0              1.0
# Karimnagar                  1.0    1.0    1.0              1.0
# ...

# %%
t=list(numerical_data.loc[:,'Adilabad':].columns)
t.append('Urban')
t.append('Rural')

# %%
plt.figure(figsize=(20,40))
for col in list(enumerate(t)):
    plt.subplot(11,3,col[0]+1)
    sns.regplot(x=col[1],y='Total (2019-20)',data=numerical_data,fit_reg=True,scatter=True)

# %%
sns.pairplot(dfnew,x_vars=['Adilabad','Nirmal'],y_vars='Indicators (2019-20)',kind='hist')
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=dfnew,x='Urban',y='Indicators (2019-20)')
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.pie(dfnew.Rural,labels=dfnew.Hyderabad)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a503d8d610>,
# ...
#  [Text(0.743756305435208, 0.8104483685746858, '18.5'),
#   Text(-0.7437563054352082, -0.8104483685746856, '58.2')])

# %%
plt.pie(dfnew.Rural,labels=dfnew.loc[:,'Indicators (2019-20)'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a503ee0b80>,
# ...
#  [Text(0.743756305435208, 0.8104483685746858, '30. Health worker ever talked to female non-users about family planning (%)'),
#   Text(-0.7437563054352082, -0.8104483685746856, '31. Current users ever told about side effects of current method8 (%)')])

# %%
df_t=numerical_data
